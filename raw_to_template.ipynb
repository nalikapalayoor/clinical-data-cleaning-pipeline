# %%
import pandas as pd
import re
from datetime import datetime

# %% [markdown]
# ### Load in spreadsheets and create final df outline

# %%
# define these

template= '1Bulk_sample_template_V11.xlsx'
raw= 'PRB_LB_0325_raw.xlsx'
sheet_name= 'Clinical Data'
raw_header= 1
template_header= 1

# %%
# load in the data

template= pd.read_excel(template, header= template_header)
raw= pd.read_excel(raw, sheet_name= sheet_name, header= raw_header)
final= pd.DataFrame(index= raw.index, columns= template.columns)

# %% [markdown]
# ### Clean biomarker data (includes menopausal status)

# %%
# menopausal status
biomarker_cols= ["Biomarker 1", "Biomarker 2", "Biomarker 3", "Biomarker 4", "Biomarker 5", "Biomarker 6"]

menopause_mapping= {
    "premenopause": ["pre menopause"],
    "perimenopause": ["peri menopause"],
    "menopause": ["menopause"],
    "postmenopause": ["post menopause"]
}

def extract_menopause_status(row):
    for col in biomarker_cols:
        val= row.get(col)
        if pd.isna(val):
            continue
        val_str= str(val).strip().lower()

        if "menopause status" in val_str:
            parts= val_str.split("=")
            if len(parts)>1:
                raw_status= parts[1].strip().lower()

                for clean_val, options in menopause_mapping.items():
                    if raw_status in [opt.lower() for opt in options]:
                        return clean_val
                return "Unknown"
    return pd.NA

final["Menopausal Status"]= raw.apply(extract_menopause_status, axis=1)

# %%
# biomarkers

biomarker_lookup = {
    "HER2": ["her2"],
    "ER": ["er", "estrogen receptor"],
    "PR": ["pr", "progesterone receptor"],
    "FISH": ["fish"],
    "PDL1": ["pdl1"],
    "ALK": ["alk"],
    "ROS": ["ros"],
    "EGFR": ["egfr"],
    "KRAS": ["kras"],
    "PIK3CA": ["pik3ca"],
    "ESR1": ["esr1"],
    "AR": ["ar"],
}

pos_neg_mapping = {
    "Positive": [
        "positive", "strong positive", "weak positive", "2+", "3+", "12", "8", "6", "9", "3", ">= 10", ">=10"
    ],
    "Negative": [
        "negative", "0", "none", "not detected", "less than 10%", "less than 10", "1+"
    ]
}

def interpret_her2_status(val):
    if pd.isna(val):
        return pd.NA

    val = str(val).lower()
    her2_score = None
    fish_result = None

    match_ihc = re.search(r"her2\s*=\s*([0-3]\+?)", val)
    if match_ihc:
        her2_score = match_ihc.group(1)

    if "fish" in val or "ish" in val:
        if "positive" in val:
            fish_result = "positive"
        elif "negative" in val:
            fish_result = "negative"

    if her2_score in ["0", "1+"]:
        return "negative"
    elif her2_score == "3+":
        return "positive"
    elif her2_score == "2+":
        if fish_result == "positive":
            return "positive"
        elif fish_result == "negative":
            return "negative"
        else:
            return "HER2 2+ (FISH/ISH missing)"

    return pd.NA

def extract_pos_neg_biomarker(row, biomarker_cols, biomarker_lookup, pos_neg_mapping):
    results = {}

    for col in biomarker_cols:
        cell = row.get(col)
        if pd.isna(cell):
            continue
        val = str(cell).strip().lower()

        if "=" in val:
            biomarker_name, raw_result = [s.strip() for s in val.split("=", 1)]

            for template_col, raw_variants in biomarker_lookup.items():
                if biomarker_name.lower() in [v.lower() for v in raw_variants]:
                    if template_col == "HER2":
                        mapped = interpret_her2_status(val)
                    else:
                        mapped = None
                        for label, values in pos_neg_mapping.items():
                            for v in values:
                                if v.lower() in raw_result:
                                    mapped = label
                                    break
                            if mapped:
                                break
                        if not mapped:
                            mapped = raw_result
                    results[template_col] = mapped
    return results

biomarker_cols = ["Biomarker 1", "Biomarker 2", "Biomarker 3", "Biomarker 4", "Biomarker 5", "Biomarker 6"]

biomarker_data = raw.apply(
    lambda row: extract_pos_neg_biomarker(row, biomarker_cols, biomarker_lookup, pos_neg_mapping),
    axis=1
)

for idx, result in biomarker_data.items():
    for col, val in result.items():
        final.at[idx, col] = val

# %% [markdown]
# ### Map any columns that just need basic cleaning

# %%
# map columns to eachother

column_mapping= {
    "Date of Blood Draw/Cell Collection": "Date of blood collection [yyyy-mm-dd]",
    "Time of Draw": "Date of blood collection [yyyy-mm-dd]",
    "ExternalId": "Sample ID\nconsecutive",
    "Stabilizer": "Collection Tube Type",
    "Gender": "Gender",
    "Single or Double Spun": "Single or Double Spun",
    "Height": "Body height [cm]",
    "Sample Timepoint": "Blood sample timepoint",
    "TNM": "TNM",
    "Stage": "Stage",
    "Morphology Code": "Morphology code",
    "Description of Morphology Code": "Description of morphology code",
    "ExPatientId": "Patient ID\nconsecutive"  
}

# %%
# cleaning functions - one for each template column that just needs basic cleaning/mapping


def clean_date(val):
    try:
        return pd.to_datetime(val).strftime("%Y-%m-%d")
    except:
        return pd.NA

def clean_time(val):
    try: 
        return pd.to_datetime(val).strftime("%I:%M:%S %p")
    except: 
        return pd.NA

# function factory for basic mapping cleaning
def make_cleaner(mapping_dict):
    '''
    returns a cleaning function that maps raw values to the standard values
    '''
    lookup= {}
    for standard_val, raw_options in mapping_dict.items():
        for raw_val in raw_options:
            lookup[str(raw_val).strip().lower()]= standard_val
    def cleaner(val):
        if pd.isna(val):
            return pd.NA
        val_str= str(val).strip().lower()
        return lookup.get(val_str, pd.NA)
    return cleaner

# create functions from function factory
clean_stabilizer= make_cleaner({
    "Streck": ["Streck Cell-Free DNA BCT"]
})

clean_gender= make_cleaner({
    "Male": ['m', 'male', 'M', 'Male'],
    "Female": ['f', 'female', 'F', 'Female']
})

clean_single_double= make_cleaner({
    "Single": ['single', 'Single'],
    "Double": ['double', 'Double']
})

clean_sample_timepoint= make_cleaner({
    "treatment-naïve": ["Initial-0"]
})

clean_stage= make_cleaner({
    "I": ["I", "IA", "IB"],
    "II": ["II", "IIA", "IIB"],
    "III": ["III", "IIIA", "IIIB"],
    "IV": ["IV", "IVA", "IVB"]
})

# %%
# transformation registry

transformations= {
    "Date of Blood Draw/Cell Collection": clean_date,
    "Time of Draw": clean_time,
    "Stabilizer": clean_stabilizer,
    "Gender": clean_gender,
    "Single or Double Spun": clean_single_double,
    "Sample Timepoint": clean_sample_timepoint,
    "Stage": clean_stage
}

# %% [markdown]
# ### Functions for columns that need to be calculated

# %%
def calculate_age(birth_val, collection_date):
    if pd.isna(birth_val) or pd.isna(collection_date):
        return pd.NA
    try:
        birth_str= str(birth_val).strip()
        if len(birth_str)== 4 and birth_str.isdigit():
            birth_date= pd.to_datetime(f"{birth_str}-01-01")
        else:
            birth_date= pd.to_datetime(birth_str, errors= "coerce")
        collection_dt= pd.to_datetime(collection_date, errors= "coerce")

        age= (collection_dt-birth_date).days // 365
        return age
    except:
        return pd.NA

def calculate_elapsed_days(row, start_col, end_col):
    start_val= row.get(start_col)
    end_val= row.get(end_col)

    if pd.isna(start_val):
        return pd.NA
    if pd.isna(end_val):
        return pd.NA
    try:
        start_date= pd.to_datetime(start_val, errors= "coerce")
        end_date= pd.to_datetime(end_val, errors= "coerce")

        if pd.isna(start_date) or pd.isna(end_date):
            return pd.NA

        delta= (end_date-start_date).days
        return delta if delta >= 0 else pd.NA
    except:
        return pd.NA

# %%
# Create column for duration between cancer diganosis and blood draw

final["Duration between Cancer Diagnosis and Blood Draw (days)"] = raw.apply(
    lambda row: calculate_elapsed_days(row, "Date of cancer diagnosis [yyyy-mm-dd]", "Date of blood collection [yyyy-mm-dd]"), axis=1)

# create a column for duration between tnm staging and blood draw
final["Duration between TNM Staging and Blood Draw (days)"] = raw.apply(
    lambda row: calculate_elapsed_days(row, "Date of TNM staging  [yyyy-mm-dd]", "Date of blood collection [yyyy-mm-dd]"), axis=1)

# create a column for age at the time of blood collection
final["AgeAtCollection"]= raw.apply(
    lambda row: calculate_age(row["Year of birth"], row["Date of blood collection [yyyy-mm-dd]"]), axis=1)

# %% [markdown]
# ### Define columns that are not pulled from the raw data

# %%
# columns that are not pulled from raw data
fixed_values= {
    "Organism": "Human",
    "Data Transformer": "Nalika Palayoor",
    "Date of Transformation": "17-Jul-2025",
    "SpecimenType": "Plasma",
    "Condition": "cancer",
    "Diagnostic Condition": "breast cancer",
    "Hemolysis": "no hemolysis",
    "Project": "PB-2881",
    "ContainerType": "tube",
    "RNA-Sequencing Available": "No",
    "Source": "Indivumed",
    "Country": "Germany"
}

for col,val in fixed_values.items():
    if col in final.columns:
        final[col]= val

# %% [markdown]
# ### Create final dataframe

# %%
for template_col in column_mapping:
    raw_col= column_mapping[template_col]
    if raw_col in raw.columns:
        if template_col in transformations:
            final[template_col]= raw[raw_col].apply(transformations[template_col])
        else:
            final[template_col]= raw[raw_col]

# %%
pd.set_option("display.max_columns",None)
final.head(50)
# Out:
#    ExternalId Received Date ContainerType Volume_uL TubeBarcode Concentration  \
# 0   408_BD T0           NaN          tube       NaN         NaN           NaN
# 1   409_BD T0           NaN          tube       NaN         NaN           NaN
# 2   410_BD T0           NaN          tube       NaN         NaN           NaN
# 3   411_BD T0           NaN          tube       NaN         NaN           NaN
# 4   412_BD T0           NaN          tube       NaN         NaN           NaN
# 5   413_BD T0           NaN          tube       NaN         NaN           NaN
# 6   414_BD T0           NaN          tube       NaN         NaN           NaN
# 7   415_BD T0           NaN          tube       NaN         NaN           NaN
# 8   416_BD T0           NaN          tube       NaN         NaN           NaN
# 9   417_BD T0           NaN          tube       NaN         NaN           NaN
# 10  418_BD T0           NaN          tube       NaN         NaN           NaN
# 11  419_BD T0           NaN          tube       NaN         NaN           NaN
# 12  420_BD T0           NaN          tube       NaN         NaN           NaN
# 13  421_BD T0           NaN          tube       NaN         NaN           NaN
# 14  422_BD T0           NaN          tube       NaN         NaN           NaN
# 15  423_BD T0           NaN          tube       NaN         NaN           NaN
# 16  424_BD T0           NaN          tube       NaN         NaN           NaN
# 17  425_BD T0           NaN          tube       NaN         NaN           NaN
# 18  426_BD T0           NaN          tube       NaN         NaN           NaN
# 19  427_BD T0           NaN          tube       NaN         NaN           NaN
# 20  428_BD T0           NaN          tube       NaN         NaN           NaN
# 21  429_BD T0           NaN          tube       NaN         NaN           NaN
# 22  430_BD T0           NaN          tube       NaN         NaN           NaN
# 23  431_BD T0           NaN          tube       NaN         NaN           NaN
# 24  432_BD T0           NaN          tube       NaN         NaN           NaN
# 25  433_BD T0           NaN          tube       NaN         NaN           NaN
# 26  434_BD T0           NaN          tube       NaN         NaN           NaN
# 27  435_BD T0           NaN          tube       NaN         NaN           NaN
# 28  436_BD T0           NaN          tube       NaN         NaN           NaN
# 29  437_BD T0           NaN          tube       NaN         NaN           NaN
# 30  438_BD T0           NaN          tube       NaN         NaN           NaN
# 31  439_BD T0           NaN          tube       NaN         NaN           NaN
# 32  440_BD T0           NaN          tube       NaN         NaN           NaN
# 33  441_BD T0           NaN          tube       NaN         NaN           NaN
# 34  442_BD T0           NaN          tube       NaN         NaN           NaN
# 35  443_BD T0           NaN          tube       NaN         NaN           NaN
# 36  444_BD T0           NaN          tube       NaN         NaN           NaN
# 37  445_BD T0           NaN          tube       NaN         NaN           NaN
# 38  446_BD T0           NaN          tube       NaN         NaN           NaN
# 39  447_BD T0           NaN          tube       NaN         NaN           NaN
# 40  448_BD T0           NaN          tube       NaN         NaN           NaN
# 41  449_BD T0           NaN          tube       NaN         NaN           NaN
# 42  450_BD T0           NaN          tube       NaN         NaN           NaN
# 43  451_BD T0           NaN          tube       NaN         NaN           NaN
# 44  452_BD T0           NaN          tube       NaN         NaN           NaN
# 45  453_BD T0           NaN          tube       NaN         NaN           NaN
# 46  454_BD T0           NaN          tube       NaN         NaN           NaN
# 47  455_BD T0           NaN          tube       NaN         NaN           NaN
# 48  456_BD T0           NaN          tube       NaN         NaN           NaN
# 49  457_BD T0           NaN          tube       NaN         NaN           NaN
#
#    ConcentrationUnits Organism Stabilizer Single or Double Spun  \
# 0                 NaN    Human     Streck                Double
# 1                 NaN    Human     Streck                Double
# 2                 NaN    Human     Streck                Double
# 3                 NaN    Human     Streck                Double
# 4                 NaN    Human     Streck                Double
# 5                 NaN    Human     Streck                Double
# 6                 NaN    Human     Streck                Double
# 7                 NaN    Human     Streck                Double
# 8                 NaN    Human     Streck                Double
# 9                 NaN    Human     Streck                Double
# 10                NaN    Human     Streck                Double
# 11                NaN    Human     Streck                Double
# 12                NaN    Human     Streck                Double
# 13                NaN    Human     Streck                Double
# 14                NaN    Human     Streck                Double
# 15                NaN    Human     Streck                Double
# 16                NaN    Human     Streck                Double
# 17                NaN    Human     Streck                Double
# 18                NaN    Human     Streck                Double
# 19                NaN    Human     Streck                Double
# 20                NaN    Human     Streck                Double
# 21                NaN    Human     Streck                Double
# 22                NaN    Human     Streck                Double
# 23                NaN    Human     Streck                Double
# 24                NaN    Human     Streck                Double
# 25                NaN    Human     Streck                Double
# 26                NaN    Human     Streck                Double
# 27                NaN    Human     Streck                Double
# 28                NaN    Human     Streck                Double
# 29                NaN    Human     Streck                Double
# 30                NaN    Human     Streck                Double
# 31                NaN    Human     Streck                Double
# 32                NaN    Human     Streck                Double
# 33                NaN    Human     Streck                Double
# 34                NaN    Human     Streck                Double
# 35                NaN    Human     Streck                Double
# 36                NaN    Human     Streck                Double
# 37                NaN    Human     Streck                Double
# 38                NaN    Human     Streck                Double
# 39                NaN    Human     Streck                Double
# 40                NaN    Human     Streck                Double
# 41                NaN    Human     Streck                Double
# 42                NaN    Human     Streck                Double
# 43                NaN    Human     Streck                Double
# 44                NaN    Human     Streck                Double
# 45                NaN    Human     Streck                Double
# 46                NaN    Human     Streck                Double
# 47                NaN    Human     Streck                Double
# 48                NaN    Human     Streck                Double
# 49                NaN    Human     Streck                Double
#
#    Processing Method Processing Time(hrs) Freeze Thaw Status     Hemolysis  \
# 0                NaN                  NaN                NaN  no hemolysis
# 1                NaN                  NaN                NaN  no hemolysis
# 2                NaN                  NaN                NaN  no hemolysis
# 3                NaN                  NaN                NaN  no hemolysis
# 4                NaN                  NaN                NaN  no hemolysis
# 5                NaN                  NaN                NaN  no hemolysis
# 6                NaN                  NaN                NaN  no hemolysis
# 7                NaN                  NaN                NaN  no hemolysis
# 8                NaN                  NaN                NaN  no hemolysis
# 9                NaN                  NaN                NaN  no hemolysis
# 10               NaN                  NaN                NaN  no hemolysis
# 11               NaN                  NaN                NaN  no hemolysis
# 12               NaN                  NaN                NaN  no hemolysis
# 13               NaN                  NaN                NaN  no hemolysis
# 14               NaN                  NaN                NaN  no hemolysis
# 15               NaN                  NaN                NaN  no hemolysis
# 16               NaN                  NaN                NaN  no hemolysis
# 17               NaN                  NaN                NaN  no hemolysis
# 18               NaN                  NaN                NaN  no hemolysis
# 19               NaN                  NaN                NaN  no hemolysis
# 20               NaN                  NaN                NaN  no hemolysis
# 21               NaN                  NaN                NaN  no hemolysis
# 22               NaN                  NaN                NaN  no hemolysis
# 23               NaN                  NaN                NaN  no hemolysis
# 24               NaN                  NaN                NaN  no hemolysis
# 25               NaN                  NaN                NaN  no hemolysis
# 26               NaN                  NaN                NaN  no hemolysis
# 27               NaN                  NaN                NaN  no hemolysis
# 28               NaN                  NaN                NaN  no hemolysis
# 29               NaN                  NaN                NaN  no hemolysis
# 30               NaN                  NaN                NaN  no hemolysis
# 31               NaN                  NaN                NaN  no hemolysis
# 40  12:06:00 PM        NaN         NaN                NaN     NaN        NaN
# 41  01:27:00 PM        NaN         NaN                NaN     NaN        NaN
# 42  09:35:00 AM        NaN         NaN                NaN     NaN        NaN
# 43  10:00:00 AM        NaN         NaN                NaN     NaN        NaN
# 44  01:39:00 PM        NaN         NaN                NaN     NaN        NaN
# 45  10:15:00 AM        NaN         NaN                NaN     NaN        NaN
# 46  07:43:00 AM        NaN         NaN                NaN     NaN        NaN
# 47  07:57:00 AM        NaN         NaN                NaN     NaN        NaN
# 48  09:02:00 AM        NaN         NaN                NaN     NaN        NaN
# 49  10:00:00 AM        NaN         NaN                NaN     NaN        NaN
#
#    Surgery Type Tumor Tissue Type Data Transformer Date of Transformation  \
# 0           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 1           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 2           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 3           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 4           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 5           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 6           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 7           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 8           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 9           NaN               NaN  Nalika Palayoor            17-Jul-2025
# 10          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 11          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 12          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 13          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 14          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 15          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 16          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 17          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 18          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 19          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 20          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 21          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 22          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 23          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 24          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 25          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 26          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 27          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 28          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 29          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 30          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 31          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 32          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 33          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 34          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 35          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 36          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 37          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 38          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 39          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 40          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 41          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 42          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 43          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 44          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 45          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 46          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 47          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 48          NaN               NaN  Nalika Palayoor            17-Jul-2025
# 49          NaN               NaN  Nalika Palayoor            17-Jul-2025
#
#    Other Sample Notes ExSpecimenId Collection Site SpecimenType Condition  \
# 0                 NaN          NaN             NaN       Plasma    cancer
# 1                 NaN          NaN             NaN       Plasma    cancer
# 2                 NaN          NaN             NaN       Plasma    cancer
# 3                 NaN          NaN             NaN       Plasma    cancer
# 4                 NaN          NaN             NaN       Plasma    cancer
# 5                 NaN          NaN             NaN       Plasma    cancer
# 6                 NaN          NaN             NaN       Plasma    cancer
# 7                 NaN          NaN             NaN       Plasma    cancer
# 8                 NaN          NaN             NaN       Plasma    cancer
# 9                 NaN          NaN             NaN       Plasma    cancer
# 10                NaN          NaN             NaN       Plasma    cancer
# 11                NaN          NaN             NaN       Plasma    cancer
# 12                NaN          NaN             NaN       Plasma    cancer
# 13                NaN          NaN             NaN       Plasma    cancer
# 14                NaN          NaN             NaN       Plasma    cancer
# 15                NaN          NaN             NaN       Plasma    cancer
# 16                NaN          NaN             NaN       Plasma    cancer
# 17                NaN          NaN             NaN       Plasma    cancer
# 18                NaN          NaN             NaN       Plasma    cancer
# 19                NaN          NaN             NaN       Plasma    cancer
# 20                NaN          NaN             NaN       Plasma    cancer
# 21                NaN          NaN             NaN       Plasma    cancer
# 22                NaN          NaN             NaN       Plasma    cancer
# 23                NaN          NaN             NaN       Plasma    cancer
# 24                NaN          NaN             NaN       Plasma    cancer
# 25                NaN          NaN             NaN       Plasma    cancer
# 26                NaN          NaN             NaN       Plasma    cancer
# 27                NaN          NaN             NaN       Plasma    cancer
# 28                NaN          NaN             NaN       Plasma    cancer
# 29                NaN          NaN             NaN       Plasma    cancer
# 30                NaN          NaN             NaN       Plasma    cancer
# 31                NaN          NaN             NaN       Plasma    cancer
# 32                NaN          NaN             NaN       Plasma    cancer
# 33                NaN          NaN             NaN       Plasma    cancer
# 34                NaN          NaN             NaN       Plasma    cancer
# 35                NaN          NaN             NaN       Plasma    cancer
# 36                NaN          NaN             NaN       Plasma    cancer
# 37                NaN          NaN             NaN       Plasma    cancer
# 38                NaN          NaN             NaN       Plasma    cancer
# 39                NaN          NaN             NaN       Plasma    cancer
# 40                NaN          NaN             NaN       Plasma    cancer
# 41                NaN          NaN             NaN       Plasma    cancer
# 42                NaN          NaN             NaN       Plasma    cancer
# 43                NaN          NaN             NaN       Plasma    cancer
# 44                NaN          NaN             NaN       Plasma    cancer
# 45                NaN          NaN             NaN       Plasma    cancer
# 46                NaN          NaN             NaN       Plasma    cancer
# 47                NaN          NaN             NaN       Plasma    cancer
# 48                NaN          NaN             NaN       Plasma    cancer
# 49                NaN          NaN             NaN       Plasma    cancer
#
#    Diagnostic Condition Histology  Height Weight  BMI  \
# 0         breast cancer       NaN   160.0    NaN  NaN
# 1         breast cancer       NaN   160.0    NaN  NaN
# 2         breast cancer       NaN   175.0    NaN  NaN
# 3         breast cancer       NaN   169.0    NaN  NaN
# 4         breast cancer       NaN   166.0    NaN  NaN
# 5         breast cancer       NaN   175.0    NaN  NaN
# 6         breast cancer       NaN   168.0    NaN  NaN
# 7         breast cancer       NaN   162.0    NaN  NaN
# 8         breast cancer       NaN   158.0    NaN  NaN
# 9         breast cancer       NaN   168.0    NaN  NaN
# 10        breast cancer       NaN   158.0    NaN  NaN
# 11        breast cancer       NaN   156.0    NaN  NaN
# 12        breast cancer       NaN   178.0    NaN  NaN
# 13        breast cancer       NaN   157.0    NaN  NaN
# 14        breast cancer       NaN   161.0    NaN  NaN
# 15        breast cancer       NaN   152.0    NaN  NaN
# 16        breast cancer       NaN   160.0    NaN  NaN
# 17        breast cancer       NaN   155.0    NaN  NaN
# 18        breast cancer       NaN   155.0    NaN  NaN
# 19        breast cancer       NaN   163.0    NaN  NaN
# 20        breast cancer       NaN   159.0    NaN  NaN
# 21        breast cancer       NaN   150.0    NaN  NaN
# 22        breast cancer       NaN   182.0    NaN  NaN
# 23        breast cancer       NaN   157.0    NaN  NaN
# 24        breast cancer       NaN   160.0    NaN  NaN
# 25        breast cancer       NaN   166.0    NaN  NaN
# 26        breast cancer       NaN   172.0    NaN  NaN
# 27        breast cancer       NaN   175.0    NaN  NaN
# 28        breast cancer       NaN   160.0    NaN  NaN
# 29        breast cancer       NaN     NaN    NaN  NaN
# 30        breast cancer       NaN   166.0    NaN  NaN
# 31        breast cancer       NaN     NaN    NaN  NaN
# 32        breast cancer       NaN   159.0    NaN  NaN
# 33        breast cancer       NaN   167.0    NaN  NaN
# 34        breast cancer       NaN   160.0    NaN  NaN
# 35        breast cancer       NaN   174.0    NaN  NaN
# 36        breast cancer       NaN   170.0    NaN  NaN
# 37        breast cancer       NaN   158.0    NaN  NaN
# 38        breast cancer       NaN   172.0    NaN  NaN
# 39        breast cancer       NaN   173.0    NaN  NaN
# 40        breast cancer       NaN   165.0    NaN  NaN
# 41        breast cancer       NaN   146.0    NaN  NaN
# 42        breast cancer       NaN   173.0    NaN  NaN
# 43        breast cancer       NaN   172.0    NaN  NaN
# 44        breast cancer       NaN   165.0    NaN  NaN
# 45        breast cancer       NaN   164.0    NaN  NaN
# 46        breast cancer       NaN   172.0    NaN  NaN
# 47        breast cancer       NaN   169.0    NaN  NaN
# 48        breast cancer       NaN   164.0    NaN  NaN
# 49        breast cancer       NaN   165.0    NaN  NaN
#
#     Duration between Cancer Diagnosis and Blood Draw (days)  \
# 0                                                   5
# 1                                                  33
# 2                                                  28
# 3                                                  38
# 4                                                  44
# 5                                                  62
# 6                                                  19
# 7                                                  45
# 8                                                  35
# 9                                                  33
# 10                                                 27
# 11                                                 39
# 12                                                  9
# 13                                                 36
# 14                                                 52
# 15                                                 31
# 16                                                 30
# 17                                                 23
# 18                                                 73
# 19                                                  8
# 20                                                  3
# 21                                                  4
# 22                                                 28
# 23                                                 35
# 24                                                 56
# 25                                                 24
# 26                                                 28
# 27                                                 23
# 28                                                 17
# 29                                                 62
# 30                                                 30
# 31                                                 22
# 32                                                 28
# 33                                                 55
# 34                                                 64
# 35                                                 79
# 36                                                 12
# 37                                                 41
# 38                                                 30
# 39                                                 50
# 40                                                 14
# 41                                                 25
# 42                                                 15
# 43                                                 21
# 44                                                 28
# 45                                                 12
# 46                                                 44
# 47                                                 52
# 48                                                 43
# 49                                                 29
#
#    Duration between Metastatic Diagnosis and Blood Draw (days)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    Sample Timepoint Sample Timepoint Description  AgeAtCollection  \
# 0   treatment-naïve                          NaN               57
# 1   treatment-naïve                          NaN               74
# 2   treatment-naïve                          NaN               71
# 3   treatment-naïve                          NaN               56
# 4   treatment-naïve                          NaN               65
# 5   treatment-naïve                          NaN               70
# 6   treatment-naïve                          NaN               62
# 7   treatment-naïve                          NaN               86
# 8   treatment-naïve                          NaN               77
# 9   treatment-naïve                          NaN               55
# 10  treatment-naïve                          NaN               51
# 11  treatment-naïve                          NaN               80
# 12  treatment-naïve                          NaN               52
# 13  treatment-naïve                          NaN               81
# 14  treatment-naïve                          NaN               56
# 15  treatment-naïve                          NaN               59
# 16  treatment-naïve                          NaN               64
# 17  treatment-naïve                          NaN               83
# 18  treatment-naïve                          NaN               68
# 19  treatment-naïve                          NaN               57
# 20  treatment-naïve                          NaN               64
# 21  treatment-naïve                          NaN               84
# 22  treatment-naïve                          NaN               83
# 23  treatment-naïve                          NaN               61
# 24  treatment-naïve                          NaN               78
# 25  treatment-naïve                          NaN               33
# 26  treatment-naïve                          NaN               68
# 27  treatment-naïve                          NaN               48
# 28  treatment-naïve                          NaN               67
# 29  treatment-naïve                          NaN               82
# 30  treatment-naïve                          NaN               72
# 31  treatment-naïve                          NaN               82
# 32  treatment-naïve                          NaN               66
# 33  treatment-naïve                          NaN               75
# 34  treatment-naïve                          NaN               77
# 35  treatment-naïve                          NaN               59
# 36  treatment-naïve                          NaN               47
# 37  treatment-naïve                          NaN               59
# 38  treatment-naïve                          NaN               78
# 39  treatment-naïve                          NaN               57
# 40  treatment-naïve                          NaN               84
# 41  treatment-naïve                          NaN               88
# 42  treatment-naïve                          NaN               30
# 43  treatment-naïve                          NaN               77
# 44  treatment-naïve                          NaN               47
# 45  treatment-naïve                          NaN               71
# 46  treatment-naïve                          NaN               81
# 47  treatment-naïve                          NaN               68
# 48  treatment-naïve                          NaN               80
# 49  treatment-naïve                          NaN               88
#
#    Detailed Anatomical Location Grade Tumor Size                          TNM  \
# 0                           NaN   NaN        NaN                 cT4c cN1 cM1
# 1                           NaN   NaN        NaN               rT0 pN0 pM1 GX
# 2                           NaN   NaN        NaN     rT0 cN0 pM1 G3 LX VX PnX
# 3                           NaN   NaN        NaN               cT2 cN0 cM1 G3
# 4                           NaN   NaN        NaN              cT4b cNX cM1 G2
# 5                           NaN   NaN        NaN           cT4b cNX cM1 G1 L1
# 6                           NaN   NaN        NaN                  cT3 cNX cM1
# 7                           NaN   NaN        NaN               cT2 cN0 cM1 G2
# 8                           NaN   NaN        NaN                  cT4 cN1 cM1
# 9                           NaN   NaN        NaN     cT2 cN1 cM1 G3 L0 V0 PnX
# 10                          NaN   NaN        NaN               cT4 cN1 cM1 G3
# 11                          NaN   NaN        NaN                 rT4 rN2a rM1
# 12                          NaN   NaN        NaN             rcT1c cN1 cM1 G2
# 13                          NaN   NaN        NaN                cT4d cN3a cM1
# 14                          NaN   NaN        NaN             cT4b cN3c cM1 G3
# 15                          NaN   NaN        NaN             cT4d cN3c cM1 G2
# 16                          NaN   NaN        NaN             cT4b cN3c cM1 G3
# 17                          NaN   NaN        NaN             cT4b cN3a cM1 G3
# 18                          NaN   NaN        NaN                cT4b cN3a cM1
# 19                          NaN   NaN        NaN                cT4d cN3a cM1
# 20                          NaN   NaN        NaN              cT3 cN3a cM1 G2
# 21                          NaN   NaN        NaN                cT4d cN3a cM1
# 22                          NaN   NaN        NaN             rcT4b cN2 cM1 G3
# 23                          NaN   NaN        NaN             cT4c cN3a cM1 G3
# 24                          NaN   NaN        NaN                  cT4 cNX cM1
# 25                          NaN   NaN        NaN                  cT1 cN1 cM1
# 26                          NaN   NaN        NaN                  cT2 cN1 cM1
# 27                          NaN   NaN        NaN                 cT4b cN1 cM1
# 28                          NaN   NaN        NaN              cT4d cN3 cM1 G3
# 29                          NaN   NaN        NaN                 cT1c cN0 cM1
# 30                          NaN   NaN        NaN               cT4 cNX cM1 G2
# 31                          NaN   NaN        NaN                  cT4 cN1 cM1
# 32                          NaN   NaN        NaN               cT4 cN1 cM1 G3
# 33                          NaN   NaN        NaN             cT4b cN3c cM1 G2
# 34                          NaN   NaN        NaN               cT1 cN1 cM1 G2
# 35                          NaN   NaN        NaN                  cT4 cN2 cM1
# 36                          NaN   NaN        NaN    cT4d cN1 cM1 G3 LX VX PnX
# 37                          NaN   NaN        NaN               cT3 cN0 pM1 G3
# 38                          NaN   NaN        NaN               cT2 cN1 pM1 G3
# 39                          NaN   NaN        NaN                  cT3 cN3 cM1
# 40                          NaN   NaN        NaN              cT3 cN3a cM1 G3
# 41                          NaN   NaN        NaN               cT3 cN1 cM1 G3
# 42                          NaN   NaN        NaN  rcT0 rcNX rcM1 GX LX VX PnX
# 43                          NaN   NaN        NaN               cT2 cN1 pM1 G2
# 44                          NaN   NaN        NaN                 cT4b cN2 cM1
# 45                          NaN   NaN        NaN               cT1 cN0 cM1 G3
# 46                          NaN   NaN        NaN    cT4b cN2 cM1 G3 L1 VX PnX
# 47                          NaN   NaN        NaN     cT2 cN1 cM1 G3 L1 VX PnX
# 48                          NaN   NaN        NaN    cT4b cN1 cM1 G2 L1 VX PnX
# 49                          NaN   NaN        NaN   cT4b cN2a cM1 G3 L1 VX PnX
#
#    Duration between TNM Staging and Blood Draw (days) Stage Stage Detailed  \
# 0                                                   5    IV            NaN
# 1                                                  33    IV            NaN
# 2                                                  28    IV            NaN
# 3                                                  38    IV            NaN
# 4                                                  44    IV            NaN
# 5                                                  62    IV            NaN
# 6                                                  19    IV            NaN
# 7                                                  45    IV            NaN
# 8                                                  35    IV            NaN
# 9                                                  33    IV            NaN
# 10                                                 27    IV            NaN
# 11                                                 10    IV            NaN
# 12                                                  9    IV            NaN
# 13                                                 36    IV            NaN
# 14                                                 52    IV            NaN
# 15                                                 31    IV            NaN
# 16                                                 30    IV            NaN
# 17                                                 23    IV            NaN
# 18                                                 73    IV            NaN
# 19                                                  8    IV            NaN
# 20                                                  3    IV            NaN
# 21                                                  4    IV            NaN
# 22                                                 28    IV            NaN
# 23                                                 35    IV            NaN
# 24                                                 56    IV            NaN
# 25                                                 24    IV            NaN
# 26                                                 28    IV            NaN
# 27                                                 23    IV            NaN
# 28                                                 17    IV            NaN
# 29                                                 62    IV            NaN
# 30                                                 30    IV            NaN
# 31                                                 22    IV            NaN
# 32                                                 28    IV            NaN
# 33                                                 55    IV            NaN
# 34                                                 64    IV            NaN
# 35                                                 79    IV            NaN
# 36                                                 12    IV            NaN
# 37                                                 41    IV            NaN
# 38                                                 30    IV            NaN
# 39                                                 50    IV            NaN
# 40                                                 14    IV            NaN
# 41                                                 25    IV            NaN
# 42                                               <NA>    IV            NaN
# 43                                                 21    IV            NaN
# 44                                                 28    IV            NaN
# 45                                                 12    IV            NaN
# ...
